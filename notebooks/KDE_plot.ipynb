# %%
import sys
if '../' not in sys.path:
    sys.path.append('../')
import pandas as pd

# %%
df = pd.read_excel(r'..\..\drug-screening\data\raw\ROS1_all data randomised.xlsx')

# %%
from src.visualization.kde_plot_one_experiment import make_KDE_plot

# %%
make_KDE_plot(df).show()
