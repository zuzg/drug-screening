# %%
if '../' not in sys.path:
    sys.path.append('../')
from src.data.parse_data import *
from src.visualization.advanced_visualizations import *
import plotly.express as px

# %%
df_list = list()
for i in range(1, 9):
    df_list.append((parse_data(f'Assay {i}.xlsx'), f'Assay {i}.xlsx'))
# Out:
# Assay 1.xlsx - deleted 15 rows with invalid Transfer Status
# Assay 2.xlsx - deleted 4 rows with invalid Transfer Status
# Assay 3.xlsx - deleted 2 rows with invalid Transfer Status

# %%
combined = combine_assays(df_list)
# combined.head()
# Out:
# c:\Users\agata\anaconda3\envs\data-mining2\lib\site-packages\pandas\core\reshape\merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)

# %%
df_prepared = get_activation_inhibition(combined)
# df_prepared.head()

# %%
projections = get_projections(df_prepared)
# projections.head()

# %%
plot_projection_2d(projections, feature='% ACTIVATION - Assay 2', projection='tsne')

# %%
plot_projection_2d(projections, feature='% INHIBITION - Assay 5')

# %%
projections_3d = get_projections(df_prepared, get_3d=True)

# %%
plot_projection_3d(projections_3d, feature='% ACTIVATION - Assay 2', projection='tsne')

# %%
res = plot_projection_3d(projections_3d, feature='% INHIBITION - Assay 5')
res.show()
