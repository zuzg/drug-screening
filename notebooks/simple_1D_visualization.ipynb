# %%
import sys
if '../' not in sys.path:
    sys.path.append('../')

# %% [markdown]
# # Clustering

# %%
from src.visualization.plot_1d_clustering import clustering_1D_visualization
from src.visualization.input_data_converter import convert_inpute_data

# %% [markdown]
# ### 1D-clustering

# %%
data = [[20, 25, 30, 40, 45, 60],[70, 80, 90, 100, 120],[130, 150, 170, 190, 200, 210, 220, 230]]
clustering_1D_visualization(data).show()

# %%
data = convert_inpute_data([10,15,20,25,30,40,45,60,70,80,110], [0,0,0,0,0,1,1,2,2,2,3])
clustering_1D_visualization(data).show()
